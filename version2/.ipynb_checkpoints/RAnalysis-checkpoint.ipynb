# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
owd=os.getcwd()
path=os.chdir('EOS')
EOSlist=[]
listOfEntries= os.scandir(path)
for entry in listOfEntries:
    if entry.path.endswith('dat'):
        EOSlist.append(entry.name)
os.chdir(owd)

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=8)

i=0
fig = plt.figure()
for EOS in EOSlist:
    R,M=np.loadtxt('results/'+EOS[:-4]+'/MRrhoc.dat',usecols=(0,1),unpack=True)
    maxi=np.argmax(M)+1
    pR=np.delete(R,np.s_[maxi:])
    pM=np.delete(M,np.s_[maxi:])
    MR+=plt.plot(pR,pM,'-', linewidth=1.2,label=EOS[:-4])
    i+=1
plt.xlabel(r'$R\,[km]$')
plt.ylabel(r'$M/M_{\odot}$')
plt.xlim(5,20)
l1 = plt.legend(MR[:16], [label[:-4] for label in EOSlist[:16]] , loc=1,prop={'size': 6})
l2 = plt.legend(MR[16:], [label[:-4] for label in EOSlist[16:]] , loc=2,prop={'size': 6})
plt.gca().add_artist(l1)
plt.savefig('figures/MRrels.pdf', format='pdf', dpi=1000,bbox_inches="tight")

# %% [markdown]
# # Stability

# %%
EOSlist[16:]
# Out:
# ['ms1b.dat',
#  'bsk20.dat',
#  'wff3.dat',
#  'wff1.dat',
#  'H2.dat',
#  'alf1.dat',
#  'bpal12.dat',
#  'bgn1h1.dat',
#  'eng.dat',
#  'H1.dat',
#  'mpa1.dat',
#  'ap1.dat',
#  'ms2.dat',
#  'ap3.dat',
#  'gnh3.dat',
#  'fps.dat',
#  'bsk19.dat']
